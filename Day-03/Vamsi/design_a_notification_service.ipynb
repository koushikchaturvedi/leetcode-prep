# %% [markdown]
# # Design a notification service
#
# Question: Design a notification service.

# %% [markdown]
# ## Algorithm
# Describe the high-level architecture, components, and trade-offs here.

# %%
# Architecture snippet

# Is it for a mobile, email or in-app?

# who trigger this notification

# how many notifications per day?

# This accepts notifications from other services

# it should handle high throughput

# low latency

# any service -> notification api

# notification api -> kafka queue

# send notification to channel

# kafka -> push into in-app / SMS / Email

#  For any rules check then rules stored in DB

# %% [markdown]
# ## Solution
# Write the final design solution here.

# %%
# Solution snippet

# %% [markdown]
# ## Notes
# -
