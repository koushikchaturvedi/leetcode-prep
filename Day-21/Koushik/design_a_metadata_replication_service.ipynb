# %% [markdown]
# # Design a metadata replication service
#
# Question: Design a metadata replication service.

# %% [markdown]
# ## Algorithm
# Describe the high-level architecture, components, and trade-offs here.

# %%
# Architecture snippet

# %% [markdown]
# ## Solution
# Write the final design solution here.

# %%
# Solution snippet

# %% [markdown]
# ## Notes
# -
