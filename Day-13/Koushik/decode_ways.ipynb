# %% [markdown]
# # Decode Ways
#
# Question: Given a string s, return the number of ways to decode it.
#
# LeetCode link: https://leetcode.com/problems/decode-ways/

# %% [markdown]
# ## Algorithm
# Describe the approach, pattern, and steps to solve the problem here.

# %%
# Algorithm snippet

# %% [markdown]
# ## Solution
# Write the final solution here.

# %%
# Solution snippet

# %% [markdown]
# ## Notes
# -
