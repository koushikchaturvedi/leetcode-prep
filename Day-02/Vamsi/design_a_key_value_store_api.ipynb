# %% [markdown]
# # Design a key-value store API
#
# Question: Design a key-value store API.

# %% [markdown]
# ## Algorithm
# Describe the high-level architecture, components, and trade-offs here.

# %%
# Architecture snippet
# I would start designing an API
# Endpoints
# POST /data
# GET /data
# DELETE /data
# PUT /data

# I would start as simple as hashmap as the data would at the end of operation.

# I would like retain the data so storing data in database

# %% [markdown]
# ## Solution
# Write the final design solution here.

# %%
# Solution snippet

# %% [markdown]
# ## Notes
# -
