# %% [markdown]
# # LRU Cache
#
# Question: Design and implement an LRU cache with get and put operations.
#
# LeetCode link: https://leetcode.com/problems/lru-cache/

# %% [markdown]
# ## Algorithm
# Describe the approach, pattern, and steps to solve the problem here.

# %%
# Algorithm snippet

# %% [markdown]
# ## Solution
# Write the final solution here.

# %%
# Solution snippet

# %% [markdown]
# ## Notes
# -
